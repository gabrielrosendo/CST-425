# %%
# Load dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# Plot data

# %%
# Create list with sample numeric data to perform descriptive analysis
# Data Generated with Chat GPT
house_data = pd.read_csv('house_dataset.csv')

# Plot the dataset
plt.figure(figsize=(10, 6))

# Scatter plot for Price vs Size (sqft)
plt.scatter(house_data["Size (sqft)"], house_data["Price (hundreds of thousands)"], 
            alpha=0.7, label="Price vs Size", color="blue")

# Add labels, legend, and title
plt.xlabel("Independent Variables (Size in sqft)")
plt.ylabel("Price (hundreds of thousands)")
plt.title("House Dataset: Price vs Size")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Fit Model
X = house_data[["Size (sqft)"]]
y = house_data["Price (hundreds of thousands)"]
model = LinearRegression()
model.fit(X, y)

# Plot the linear regression line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, alpha=0.7, label="Price vs Size", color="blue")
plt.plot(X, model.predict(X), color="red", label="Linear Regression Line")
plt.xlabel("Size (sqft)")
plt.ylabel("Price (hundreds of thousands)")
plt.title("House Dataset: Price vs Size with Linear Regression Line")
plt.legend()
plt.grid(True)
plt.show()
